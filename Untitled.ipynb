# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
housing = pd.read_csv("baholar.csv")
d = preprocessing.normalize(housing)
scaler = preprocessing.MinMaxScaler()

names = housing.columns
d = scaler.fit_transform(housing)

d_df = pd.DataFrame(d, columns=names)
d_df
# Out:
#     daftar  joriy_nazorat   mi  savol_javob  darsda_qatnashish  \
# 0      1.0            0.8  0.8         0.00                1.0
# 1      1.0            0.8  1.0         0.00                1.0
# 2      0.0            0.6  0.0         0.50                0.0
# 3      0.0            0.6  0.0         0.50                0.0
# 4      1.0            0.8  0.0         0.00                1.0
# 5      1.0            1.0  0.0         0.75                0.0
# 6      1.0            0.8  0.0         0.75                0.0
# 7      1.0            0.8  1.0         0.00                1.0
# 8      0.0            1.0  0.0         0.75                0.0
# 9      0.0            0.4  0.0         0.75                0.0
# 10     0.0            0.4  0.0         0.75                0.0
# 11     0.0            0.8  0.0         1.00                1.0
# 12     0.0            0.6  0.0         0.50                0.0
# 13     0.0            0.6  0.0         0.00                0.0
# ...

# %%
X_train = housing.drop("amaliyot_bahosi", axis=1)
y_train = housing["amaliyot_bahosi"]

X = d_df.drop("amaliyot_bahosi", axis=1)
y = d_df["amaliyot_bahosi"]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.fit(X, y)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:385, in BaseForest.fit(self, X, y, sample_weight)
#     378         raise ValueError(
#     379             "Sum of y is not strictly positive which "
#     380             "is necessary for Poisson regression."
#     381         )
#     383 self.n_outputs_ = y.shape[1]
# --> 385 y, expanded_class_weight = self._validate_y_class_weight(y)
#     387 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     388     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:746, in ForestClassifier._validate_y_class_weight(self, y)
#     745 def _validate_y_class_weight(self, y):
# --> 746     check_classification_targets(y)
# ...
